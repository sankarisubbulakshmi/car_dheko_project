# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\shank\Desktop\car_dheko\car_details.csv")
df
# Out:
# C:\Users\shank\AppData\Local\Temp\ipykernel_6180\3477411434.py:1: DtypeWarning: Columns (14) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(r"C:\Users\shank\Desktop\car_dheko\car_details.csv")
#           city  it      ft         bt        km transmission  ownerNo  \
# 0     banglore   0  Petrol  Hatchback  1,20,000       Manual        3
# 1     banglore   0  Petrol        SUV    32,706       Manual        2
# 2     banglore   0  Petrol  Hatchback    11,949       Manual        1
# 3     banglore   0  Petrol      Sedan    17,794       Manual        1
# 4     banglore   0  Diesel        SUV    60,000       Manual        1
# ...        ...  ..     ...        ...       ...          ...      ...
# 8364   kolkata   0  Petrol  Hatchback    10,000       Manual        1
# 8365   kolkata   0  Petrol  Hatchback  1,20,000       Manual        1
# 8366   kolkata   0  Petrol      Sedan    50,000    Automatic        3
# 8367   kolkata   0  Petrol  Hatchback    40,000       Manual        1
# 8368   kolkata   0  Diesel        SUV  1,20,000       Manual        2
#
#           owner            oem                  model  ...  SeatingCapacity  \
# 0     3rd Owner         Maruti         Maruti Celerio  ...              5.0
# 1     2nd Owner           Ford          Ford Ecosport  ...              5.0
# 2     1st Owner           Tata             Tata Tiago  ...              5.0
# 3     1st Owner        Hyundai          Hyundai Xcent  ...              5.0
# 4     1st Owner         Maruti     Maruti SX4 S Cross  ...              5.0
# ...         ...            ...                    ...  ...              ...
# 8364  1st Owner         Maruti         Maruti Celerio  ...              5.0
# 8365  1st Owner         Maruti        Maruti Alto 800  ...              5.0
# 8366  3rd Owner  Mercedes-Benz  Mercedes-Benz C-Class  ...              5.0
# 8367  1st Owner         Maruti            Maruti Ritz  ...              5.0
# 8368  2nd Owner        Renault         Renault Duster  ...              5.0
#
#       SteeringType TurningRadius   FrontBrakeType RearBrakeType  TopSpeed  \
# 0            Power    4.7 metres  Ventilated Disc          Drum  150 Kmph
# 1            Power    5.3 metres  Ventilated Disc          Drum       NaN
# 2            Power    4.9 meters             Disc          Drum  150 kmph
# 3            Power    4.7 metres            Disc           Drum  172km/hr
# 4            Power    5.2 meters  Ventilated Disc    Solid Disc  190 Kmph
# ...            ...           ...              ...           ...       ...
# 8364      Electric           NaN  Ventilated Disc          Drum       NaN
# 8365         Power    4.6 metres       Solid Disc          Drum  140 kmph
# 8366         Power   5.42 metres  Ventilated Disc    Solid Disc  230km/hr
# 8367         Power    4.7 metres  Ventilated Disc          Drum  156 Kmph
# 8368         Power    5.2 metres             Disc          Drum  168 Kmph
#
#        Acceleration          TyreType NoDoorNumbers CargoVolumn
# 0     15.05 Seconds  Tubeless, Radial           5.0  235-litres
# 1               NaN   Tubeless,Radial           4.0  352-litres
# 2      14.3 Seconds          Tubeless           5.0  242-litres
# 3      14.2 Seconds   Tubeless,Radial           4.0  407-litres
# 4        12 Seconds   Tubeless,Radial           5.0  353-litres
# ...             ...               ...           ...         ...
# 8364            NaN  Tubeless, Radial           5.0         313
# 8365     19 Seconds    Tubeless Tyres           5.0  177-litres
# 8366    8.8 Seconds   Tubeless,Radial           4.0  475-litres
# 8367     15 Seconds   Tubeless,Radial           5.0  236-liters
# 8368  14.20 Seconds   Tubeless,Radial           5.0  410-litres
#
# [8369 rows x 73 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8369 entries, 0 to 8368
# Data columns (total 73 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   city                8369 non-null   object
#  1   it                  8369 non-null   int64
#  2   ft                  8369 non-null   object
#  3   bt                  8365 non-null   object
#  4   km                  8369 non-null   object
#  5   transmission        8369 non-null   object
#  6   ownerNo             8369 non-null   int64
#  7   owner               8369 non-null   object
#  8   oem                 8369 non-null   object
#  9   model               8369 non-null   object
#  10  modelYear           8369 non-null   int64
#  11  centralVariantId    8369 non-null   int64
#  12  variantName         8369 non-null   object
#  13  price               8369 non-null   object
#  14  priceActual         1670 non-null   object
#  15  priceSaving         0 non-null      float64
#  16  priceFixedText      0 non-null      float64
#  17  trendingText1       8369 non-null   object
#  18  trendingText2       8369 non-null   object
#  19  RegistrationYear    8317 non-null   object
#  20  InsuranceValidity   8365 non-null   object
#  21  FuelType            8369 non-null   object
#  22  Seats               8363 non-null   object
#  23  KmsDriven           8367 non-null   object
#  24  RTO                 7475 non-null   object
#  25  Ownership           8337 non-null   object
#  26  EngineDisplacement  8365 non-null   object
#  27  Transmission        8369 non-null   object
#  28  YearofManufacture   8349 non-null   float64
#  29  Top_features        8369 non-null   object
#  30  Comfort             8301 non-null   object
#  31  Interior            8292 non-null   object
#  32  Exterior            8279 non-null   object
#  33  Safety              8273 non-null   object
#  34  Mileage             8082 non-null   object
#  35  Engine              8365 non-null   object
#  36  Max_Power           8309 non-null   object
#  37  Torque              8309 non-null   object
#  38  WheelSize           5386 non-null   object
#  39  Seats.1             8363 non-null   float64
#  40  Color               8366 non-null   object
#  41  EngineType          8074 non-null   object
#  42  Displacement        8365 non-null   float64
#  43  MaxPower            8309 non-null   object
#  44  MaxTorque           8309 non-null   object
#  45  NoofCylinder        8338 non-null   float64
#  46  ValuesperCylinder   8318 non-null   float64
#  47  ValueConfiguration  6153 non-null   object
#  48  FuelSupplySystem    6642 non-null   object
#  49  BoreXStroke         2405 non-null   object
#  50  CompressionRatio    1895 non-null   object
#  51  TurboCharger        7329 non-null   object
#  52  SuperCharger        6407 non-null   object
#  53  Length              8290 non-null   object
#  54  Width               8286 non-null   object
#  55  Height              8290 non-null   object
#  56  WheelBase           8206 non-null   object
#  57  FrontTread          4811 non-null   object
#  58  RearTread           4799 non-null   object
#  59  KerbWeight          8310 non-null   object
#  60  GrossWeight         3828 non-null   object
#  61  GearBox             8263 non-null   object
#  62  DriveType           6809 non-null   object
#  63  SeatingCapacity     8363 non-null   float64
#  64  SteeringType        8114 non-null   object
#  65  TurningRadius       6769 non-null   object
#  66  FrontBrakeType      8273 non-null   object
#  67  RearBrakeType       8273 non-null   object
#  68  TopSpeed            4607 non-null   object
#  69  Acceleration        4857 non-null   object
#  70  TyreType            8292 non-null   object
#  71  NoDoorNumbers       8358 non-null   float64
#  72  CargoVolumn         6776 non-null   object
# dtypes: float64(9), int64(4), object(60)
# memory usage: 4.7+ MB

# %%
pd.set_option("display.max_rows",None)

# %% [markdown]
# # null value checking

# %%
((df.isna().sum())/df.shape[0])*100
# Out:
# city                    0.000000
# it                      0.000000
# ft                      0.000000
# bt                      0.047795
# km                      0.000000
# transmission            0.000000
# ownerNo                 0.000000
# owner                   0.000000
# oem                     0.000000
# model                   0.000000
# modelYear               0.000000
# centralVariantId        0.000000
# variantName             0.000000
# price                   0.000000
# priceActual            80.045406
# priceSaving           100.000000
# priceFixedText        100.000000
# trendingText1           0.000000
# trendingText2           0.000000
# RegistrationYear        0.621341
# InsuranceValidity       0.047795
# FuelType                0.000000
# Seats                   0.071693
# KmsDriven               0.023898
# RTO                    10.682280
# Ownership               0.382363
# EngineDisplacement      0.047795
# Transmission            0.000000
# YearofManufacture       0.238977
# Top_features            0.000000
# Comfort                 0.812522
# Interior                0.920062
# Exterior                1.075397
# Safety                  1.147090
# Mileage                 3.429322
# Engine                  0.047795
# Max_Power               0.716932
# Torque                  0.716932
# WheelSize              35.643446
# Seats.1                 0.071693
# Color                   0.035847
# EngineType              3.524913
# Displacement            0.047795
# MaxPower                0.716932
# MaxTorque               0.716932
# NoofCylinder            0.370415
# ValuesperCylinder       0.609392
# ValueConfiguration     26.478671
# FuelSupplySystem       20.635679
# BoreXStroke            71.262994
# CompressionRatio       77.356912
# TurboCharger           12.426813
# SuperCharger           23.443661
# Length                  0.943960
# Width                   0.991755
# Height                  0.943960
# WheelBase               1.947664
# FrontTread             42.514040
# RearTread              42.657426
# KerbWeight              0.704983
# GrossWeight            54.259768
# GearBox                 1.266579
# DriveType              18.640220
# SeatingCapacity         0.071693
# SteeringType            3.046959
# TurningRadius          19.118174
# FrontBrakeType          1.147090
# RearBrakeType           1.147090
# TopSpeed               44.951607
# Acceleration           41.964392
# TyreType                0.920062
# NoDoorNumbers           0.131437
# CargoVolumn            19.034532
# dtype: float64

# %%
#we have more than 40%  of data is missing in priceActual,priceSaving , priceFixedText, BoreXStroke, CompressionRatio ,GrossWeight,FrontTread,RearTread,TopSpeed,Acceleration      columns so we can directly drop that columns   
df.drop(columns=["priceActual","priceSaving" , "priceFixedText", "BoreXStroke", "CompressionRatio" ,"GrossWeight","FrontTread","RearTread","TopSpeed","Acceleration"],axis=1,inplace=True)

# %%
#we can drop trendingText1,trendingText2 column cz it all same value even if we encode the data it wont make any change for model building so we can drop it
df.drop(["trendingText1"],axis=1,inplace =True)
df.drop(["trendingText2"],axis=1,inplace =True)

#km and kmsdriven contains same column so we can drop one column
df.drop(["KmsDriven"],axis=1,inplace=True)

#modelyear and registrationyear and yearof manufacture have same values so we can drop any two col which is registrationyear cz that has missing value
df.drop(["RegistrationYear"],axis=1,inplace=True)
df.drop(["YearofManufacture"],axis=1,inplace=True)

#ownerNo, owner, ownership these column contain same value so we can keep any one of the column
df.drop(["owner","Ownership"],axis=1,inplace=True)

#converted top feature colum as its lenght of each element to knw how much feature does that car have
df["Top_features"] = df["Top_features"].apply(lambda i: len(eval(i)) )

#comfort,interior,exterior,safety these columns has string value we converted topfeature so we can drop these column cz it is not important for feature training
df.drop(["Comfort","Interior","Exterior","Safety"],axis=1,inplace=True)

#seats and seats.1 and seating capacity has same value so we can drop any two column
df.drop("Seats",axis=1,inplace=True)
df.drop("SeatingCapacity",axis=1,inplace=True)

#Max_Power,MaxPower and Torque,MaxTorque has same values for we can drop one col
df.drop(["MaxPower","MaxTorque"],axis=1,inplace=True)

#Engine and EngineDisplacement and Displacement has same value so we can drop any 2 col
df.drop("EngineDisplacement",axis=1,inplace=True)
df.drop("Displacement",axis=1,inplace=True)

#transmission and Transmission has same values so we can drop any one col
df.drop("Transmission",axis=1,inplace=True)

#fueltype and ft has same value so we can drop one col
df.drop("ft",axis=1,inplace=True)

#it column has only one value which 0 it wobt make any change in model building so we can drop it
df.drop("it",axis=1,inplace=True)

# %%
df.shape
# Out:
# (8369, 43)

# %%
df.isna().sum()
# Out:
# city                     0
# bt                       4
# km                       0
# transmission             0
# ownerNo                  0
# oem                      0
# model                    0
# modelYear                0
# centralVariantId         0
# variantName              0
# price                    0
# InsuranceValidity        4
# FuelType                 0
# RTO                    894
# Top_features             0
# Mileage                287
# Engine                   4
# Max_Power               60
# Torque                  60
# WheelSize             2983
# Seats.1                  6
# Color                    3
# EngineType             295
# NoofCylinder            31
# ValuesperCylinder       51
# ValueConfiguration    2216
# FuelSupplySystem      1727
# TurboCharger          1040
# SuperCharger          1962
# Length                  79
# Width                   83
# Height                  79
# WheelBase              163
# KerbWeight              59
# GearBox                106
# DriveType             1560
# SteeringType           255
# TurningRadius         1600
# FrontBrakeType          96
# RearBrakeType           96
# TyreType                77
# NoDoorNumbers           11
# CargoVolumn           1593
# dtype: int64

# %%
#this columns also have high number of missing values and it wont give any importance in model building
df.drop(["WheelSize","ValueConfiguration"],axis=1,inplace=True)

# %%
for i in df.columns:
  if (df[i].isnull().sum()) !=0:
    print(i, df[i].isnull().sum())
# Out:
# bt 4
# InsuranceValidity 4
# RTO 894
# Mileage 287
# Engine 4
# Max_Power 60
# Torque 60
# Seats.1 6
# Color 3
# EngineType 295
# NoofCylinder 31
# ValuesperCylinder 51
# FuelSupplySystem 1727
# TurboCharger 1040
# SuperCharger 1962
# Length 79
# Width 83
# Height 79
# WheelBase 163
# KerbWeight 59
# GearBox 106
# DriveType 1560
# SteeringType 255
# TurningRadius 1600
# FrontBrakeType 96
# RearBrakeType 96
# TyreType 77
# NoDoorNumbers 11
# CargoVolumn 1593

# %%
df["SuperCharger"].value_counts()
# Out:
# SuperCharger
# No     6387
# Yes      14
# yes       3
# NO        2
# no        1
# Name: count, dtype: int64

# %%
#by this its imbalanced and have lots of  missing value we can jus drop this col
df.drop("SuperCharger",axis=1,inplace=True)

# %%
df["FuelSupplySystem"].unique()
# Out:
# array(['MPFi', 'Direct Injection', nan, 'CRDI',
#        'Electronic Injection System', 'GDi', 'MPFI', 'PGM - Fi',
#        'Direct Injection ', 'PGM-Fi', 'CRDi',
#        'Multi Point Fuel Injection', 'MPFI+LPG', 'Common-Rail type',
#        'Common Rail Direct Injection (dCi)', 'Multipoint Injection',
#        'CDI', 'PFI', 'EFI(Electronic Fuel Injection)', 'MPFI ', 'EFI',
#        'Multi-point injection', 'TSI', 'TDCi',
#        'Common rail direct injection',
#        'PGM-FI (Programmed Fuel Injection)', 'Electronic Fuel Injection',
#        'Common Rail Direct Injection', 'Common Rail', 'SEFI',
#        'Multi point Fuel Injection', 'MPI', 'Gasoline Direct Injection',
#        'MPi', 'Direct Injection Common Rail',
#        '3 Phase AC Induction Motors', 'Dual VVT-i',
#        'EFI (Electronic Fuel Injection)', 'SMPI', 'Indirect Injection',
#        'common rail system', 'GDI', 'PGM-FI (Programmed Fuel Inje',
#        'DOHC', 'EGIS', 'Mpfi', 'MFI', 'IDI', 'PGM-FI',
#        'Electronic Fuel Injection(EFI)', 'EFIC', 'TFSI', 'EFi',
#        'Direct Injection Common Rail ', 'DEDST', 'TGDi', 'CRDI ', 'D-4S',
#        'CNG', 'Multipoint injection', 'Direct injection',
#        'Intelligent-Gas Port Injection', 'DDIS',
#        'gasoline direct injection', 'MPFi ', 'ISG', 'MPFI+CNG',
#        'Common-Rail Type', 'VVT-iE', 'Direct Injectio', 'DPFi',
#        'Advanced Common Rail', 'Ti-VCT', 'Common Rail ', 'Electric',
#        'Distribution Type Fuel Injection', 'Common Rail Diesel',
#        'Common Rail Injection', 'PGM-FI (Programmed Fuel Inject',
#        'Direct Fuel Injection', 'TDi', 'EFI (Electronic Fuel Injection'],
#       dtype=object)

# %%
#since we have fueltype column it  wont make any contibution to model buildinf and have lots of  missing value we can jus drop this col
df.drop("FuelSupplySystem",axis=1,inplace=True)
df.drop(["TurningRadius","DriveType","CargoVolumn"],axis=1,inplace=True)

# %%
for i in df.columns:
  if (df[i].isnull().sum()) !=0:
    print(i, df[i].isnull().sum())
# Out:
# bt 4
# InsuranceValidity 4
# RTO 894
# Mileage 287
# Engine 4
# Max_Power 60
# Torque 60
# Seats.1 6
# Color 3
# EngineType 295
# NoofCylinder 31
# ValuesperCylinder 51
# TurboCharger 1040
# Length 79
# Width 83
# Height 79
# WheelBase 163
# KerbWeight 59
# GearBox 106
# SteeringType 255
# FrontBrakeType 96
# RearBrakeType 96
# TyreType 77
# NoDoorNumbers 11

# %%
df["TurboCharger"].isna().sum()
# Out:
# 1040

# %%
df.shape
# Out:
# (8369, 36)

# %%
df["TurboCharger"].unique()
# Out:
# array(['No', 'Yes', 'NO', nan, 'Twin', 'YES', 'no', 'twin', 'yes',
#        'Turbo'], dtype=object)

# %%
df["TurboCharger"].value_counts()
# Out:
# TurboCharger
# No       4231
# Yes      2994
# Twin       52
# NO         20
# YES        15
# no          9
# yes         5
# Turbo       2
# twin        1
# Name: count, dtype: int64

# %%
df["TurboCharger"] =df["TurboCharger"].replace({'No':'No',"Yes":"Yes",'Twin':'Twin','YES':'Yes','NO':'No','no':'No','twin':'Twin','yes':'Yes','Turbo':'Yes'})

# %%
df["TurboCharger"].value_counts()
# Out:
# TurboCharger
# No      4260
# Yes     3016
# Twin      53
# Name: count, dtype: int64

# %%
df["TurboCharger"].fillna(df["TurboCharger"].mode()[0],inplace=True)
# Out:
# C:\Users\shank\AppData\Local\Temp\ipykernel_6180\3899814413.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["TurboCharger"].fillna(df["TurboCharger"].mode()[0],inplace=True)

# %%
df["TurboCharger"].value_counts()
# Out:
# TurboCharger
# No      5300
# Yes     3016
# Twin      53
# Name: count, dtype: int64

# %%
df["RTO"].isnull().sum() #it has missing value
# Out:
# 894

# %%
#RTO column it is categorical value
#so for RTO column null values we can fill with unknown
df["RTO"].fillna("Unknown",inplace =True)
# Out:
# C:\Users\shank\AppData\Local\Temp\ipykernel_6180\1450281441.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["RTO"].fillna("Unknown",inplace =True)

# %%
df.drop("EngineType",axis=1,inplace=True)

# %%
df.dropna(subset="Mileage",inplace=True)

# %%
df.shape
# Out:
# (8082, 35)

# %%
df["SteeringType"].value_counts()
# Out:
# SteeringType
# Power         6214
# Electric      1367
# Electronic     103
# Manual          86
# Electrical      48
# power           29
# EPAS             9
# electric         1
# Name: count, dtype: int64

# %%
df["SteeringType"].fillna(df["SteeringType"].mode()[0],inplace=True)
# Out:
# C:\Users\shank\AppData\Local\Temp\ipykernel_6180\3621260120.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["SteeringType"].fillna(df["SteeringType"].mode()[0],inplace=True)

# %%
df["SteeringType"].value_counts()
# Out:
# SteeringType
# Power         6439
# Electric      1367
# Electronic     103
# Manual          86
# Electrical      48
# power           29
# EPAS             9
# electric         1
# Name: count, dtype: int64

# %%
df["WheelBase"].fillna(df["WheelBase"].mode()[0],inplace=True)
# Out:
# C:\Users\shank\AppData\Local\Temp\ipykernel_6180\2238695655.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["WheelBase"].fillna(df["WheelBase"].mode()[0],inplace=True)

# %%
for i in df.columns:
  if (df[i].isnull().sum()) !=0:
    print(i,df[i].dtype, df[i].isnull().sum())
# Out:
# bt object 3
# InsuranceValidity object 4
# Engine object 1
# Max_Power object 38
# Torque object 38
# Seats.1 float64 5
# NoofCylinder float64 1
# ValuesperCylinder float64 22
# Length object 56
# Width object 60
# Height object 56
# KerbWeight object 37
# GearBox object 62
# FrontBrakeType object 65
# RearBrakeType object 65
# TyreType object 56
# NoDoorNumbers float64 7

# %%
for i in df.columns:
  if (df[i].isnull().sum()) !=0:
    df[i].fillna(df[i].mode()[0],inplace =True)
# Out:
# C:\Users\shank\AppData\Local\Temp\ipykernel_6180\4190813605.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[i].fillna(df[i].mode()[0],inplace =True)

# %%
df.isna().sum()
# Out:
# city                 0
# bt                   0
# km                   0
# transmission         0
# ownerNo              0
# oem                  0
# model                0
# modelYear            0
# centralVariantId     0
# variantName          0
# price                0
# InsuranceValidity    0
# FuelType             0
# RTO                  0
# Top_features         0
# Mileage              0
# Engine               0
# Max_Power            0
# Torque               0
# Seats.1              0
# Color                0
# NoofCylinder         0
# ValuesperCylinder    0
# TurboCharger         0
# Length               0
# Width                0
# Height               0
# WheelBase            0
# KerbWeight           0
# GearBox              0
# SteeringType         0
# FrontBrakeType       0
# RearBrakeType        0
# TyreType             0
# NoDoorNumbers        0
# dtype: int64

# %% [markdown]
# # duplicates

# %%
df.duplicated().sum()
# Out:
# 86

# %%
df = df.drop_duplicates()
df.duplicated().sum()
# Out:
# 0

# %%
pd.set_option("display.max_columns",None)

# %%
#we already have oem col and varient names and kerbwright doest affect our model building
df.drop(["model",'centralVariantId', 'variantName', 'KerbWeight',],axis = 1,inplace=True)
# Out:
# C:\Users\shank\AppData\Local\Temp\ipykernel_6180\2925335785.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(["model",'centralVariantId', 'variantName', 'KerbWeight',],axis = 1,inplace=True)

# %%
df.columns
# Out:
# Index(['city', 'bt', 'km', 'transmission', 'ownerNo', 'oem', 'modelYear',
#        'price', 'InsuranceValidity', 'FuelType', 'RTO', 'Top_features',
#        'Mileage', 'Engine', 'Max_Power', 'Torque', 'Seats.1', 'Color',
#        'NoofCylinder', 'ValuesperCylinder', 'TurboCharger', 'Length', 'Width',
#        'Height', 'WheelBase', 'GearBox', 'SteeringType', 'FrontBrakeType',
#        'RearBrakeType', 'TyreType', 'NoDoorNumbers'],
#       dtype='object')

# %%
df.head(3)
# Out:
#        city         bt        km transmission  ownerNo     oem  modelYear  \
# 0  banglore  Hatchback  1,20,000       Manual        3  Maruti       2015
# 1  banglore        SUV    32,706       Manual        2    Ford       2018
# 2  banglore  Hatchback    11,949       Manual        1    Tata       2018
#
#          price      InsuranceValidity FuelType   RTO  Top_features  \
# 0     ₹ 4 Lakh  Third Party insurance   Petrol  KA51             8
# 1  ₹ 8.11 Lakh          Comprehensive   Petrol  KA05             9
# 2  ₹ 5.85 Lakh          Comprehensive   Petrol  KA03             9
#
#       Mileage   Engine  Max_Power Torque  Seats.1  Color  NoofCylinder  \
# 0   23.1 kmpl   998 CC   67.04bhp   90Nm      5.0  White           3.0
# 1     17 kmpl  1497 CC  121.31bhp  150Nm      5.0  White           3.0
# 2  23.84 kmpl  1199 CC      84bhp  114Nm      5.0    Red           3.0
#
#    ValuesperCylinder TurboCharger  Length   Width  Height WheelBase   GearBox  \
# 0                4.0           No  3715mm  1635mm  1565mm    2425mm  5 Speed
# 1                4.0           No  3998mm  1765mm  1647mm    2519mm   5 Speed
# 2                4.0           No  3746mm  1647mm  1535mm    2400mm   5 Speed
#
#   SteeringType   FrontBrakeType RearBrakeType          TyreType  NoDoorNumbers
# 0        Power  Ventilated Disc          Drum  Tubeless, Radial            5.0
# 1        Power  Ventilated Disc          Drum   Tubeless,Radial            4.0
# 2        Power             Disc          Drum          Tubeless            5.0

# %% [markdown]
# # dtype

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7996 entries, 0 to 8368
# Data columns (total 31 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   city               7996 non-null   object
#  1   bt                 7996 non-null   object
#  2   km                 7996 non-null   object
#  3   transmission       7996 non-null   object
#  4   ownerNo            7996 non-null   int64
#  5   oem                7996 non-null   object
#  6   modelYear          7996 non-null   int64
#  7   price              7996 non-null   object
#  8   InsuranceValidity  7996 non-null   object
#  9   FuelType           7996 non-null   object
#  10  RTO                7996 non-null   object
#  11  Top_features       7996 non-null   int64
#  12  Mileage            7996 non-null   object
#  13  Engine             7996 non-null   object
#  14  Max_Power          7996 non-null   object
#  15  Torque             7996 non-null   object
#  16  Seats.1            7996 non-null   float64
#  17  Color              7996 non-null   object
#  18  NoofCylinder       7996 non-null   float64
#  19  ValuesperCylinder  7996 non-null   float64
#  20  TurboCharger       7996 non-null   object
#  21  Length             7996 non-null   object
#  22  Width              7996 non-null   object
#  23  Height             7996 non-null   object
#  24  WheelBase          7996 non-null   object
#  25  GearBox            7996 non-null   object
#  26  SteeringType       7996 non-null   object
#  27  FrontBrakeType     7996 non-null   object
#  28  RearBrakeType      7996 non-null   object
#  29  TyreType           7996 non-null   object
#  30  NoDoorNumbers      7996 non-null   float64
# dtypes: float64(4), int64(3), object(24)
# memory usage: 2.0+ MB

# %%
df["km"] = df["km"].apply(lambda i: int(i.replace(",","")))
df["km"].dtype
# Out:
# C:\Users\shank\AppData\Local\Temp\ipykernel_6180\376696610.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["km"] = df["km"].apply(lambda i: int(i.replace(",","")))
# dtype('int64')

# %%
def convert_amount(amount):
    a = amount.split()
    if a[-1] == "Lakh":
        if len(a[0]) >1:
            a[0] =a[0].replace(".","")
            return int(a[0])*1000
        else:
            a[0] =a[0].replace(".","")
            return int(a[0])*100000
    elif a[-1] == "Crore":
        if len(a[0]) >1:
            a[0] =a[0].replace(".","")
            return int(a[0])*100000
        else:
            a[0] =a[0].replace(".","")
            return int(a[0])*10000000

df["price"] = df["price"].apply(lambda i: i.replace(",",""))
df["price"] = df["price"].apply(lambda i: i.replace("₹",""))

df["price"]= df["price"].apply(lambda i: convert_amount(i))

df["price"].dtype
# Out:
# C:\Users\shank\AppData\Local\Temp\ipykernel_6180\3528489512.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["price"] = df["price"].apply(lambda i: i.replace(",",""))
# C:\Users\shank\AppData\Local\Temp\ipykernel_6180\3528489512.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["price"] = df["price"].apply(lambda i: i.replace("₹",""))
# C:\Users\shank\AppData\Local\Temp\ipykernel_6180\3528489512.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["price"]= df["price"].apply(lambda i: convert_amount(i))
# dtype('float64')

# %%
def convert_to_float(value):
    if pd.isna(value):  # Check if the value is NaN
        return value
    else:
        value = value.replace("km/kg", "").replace("kmpl", "").replace(" ", "")

    try:
        return float(value)
    except ValueError:
        return value
df['Mileage'] = df['Mileage'].apply(convert_to_float)
# Out:
# C:\Users\shank\AppData\Local\Temp\ipykernel_6180\3542479938.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Mileage'] = df['Mileage'].apply(convert_to_float)

# %%
def convert_to_int(value):
    if pd.isna(value):  # Check if the value is NaN
        return value
    else:
        value.replace(" ","")
        return int(value.replace("CC",""))
df["Engine"] =df["Engine"].apply(convert_to_int)
df['Engine'].dtype
# Out:
# C:\Users\shank\AppData\Local\Temp\ipykernel_6180\2413124711.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Engine"] =df["Engine"].apply(convert_to_int)
# dtype('int64')

# %%
df['Max_Power'] = df['Max_Power'].str.extract(r'(\d+\.?\d*)')

# Convert extracted values to float, coercing any errors to NaN
df['Max_Power'] = pd.to_numeric(df['Max_Power'], errors='coerce')
# Out:
# C:\Users\shank\AppData\Local\Temp\ipykernel_6180\1808481948.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Max_Power'] = df['Max_Power'].str.extract(r'(\d+\.?\d*)')
# C:\Users\shank\AppData\Local\Temp\ipykernel_6180\1808481948.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Max_Power'] = pd.to_numeric(df['Max_Power'], errors='coerce')

# %%
df['Torque'] = df['Torque'].str.extract(r'(\d+\.?\d*)')

# Convert extracted values to float, coercing any errors to NaN
df['Torque'] = pd.to_numeric(df['Torque'], errors='coerce')
# Out:
# C:\Users\shank\AppData\Local\Temp\ipykernel_6180\183407563.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Torque'] = df['Torque'].str.extract(r'(\d+\.?\d*)')
# C:\Users\shank\AppData\Local\Temp\ipykernel_6180\183407563.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Torque'] = pd.to_numeric(df['Torque'], errors='coerce')

# %%
df = df.rename(columns={'Seats.1': 'Seats'})

# %%
df["NoofCylinder"] = df["NoofCylinder"].apply(lambda i: int(i))
df["ValuesperCylinder"] = df["ValuesperCylinder"].apply(lambda i: int(i))

# %%
df["Length"] = df["Length"].apply(lambda i: i.replace(",", "") if isinstance(i, str) else i)
df["Length"] = df["Length"].apply(lambda i: i[:4] if isinstance(i, str) else i)
df["Length"] = df["Length"].apply(lambda i: float(i) if isinstance(i, str) else i)
df["Length"].dtype
# Out:
# dtype('float64')

# %%
df["Width"] = df["Width"].apply(lambda i: i.replace(",", "") if isinstance(i, str) else i)
df["Width"] = df["Width"].apply(lambda i: float(i[:4]) if isinstance(i, str) else i)

# %%
df["Height"] = df["Height"].apply(lambda i: i.replace(",", "") if isinstance(i, str) else i)
df["Height"] = df["Height"].apply(lambda i: float(i[:4]) if isinstance(i, str) else i)

# %%
df["WheelBase"] = df["WheelBase"].apply(lambda i: i.replace(",", "") if isinstance(i, str) else i)
df["WheelBase"] = df["WheelBase"].apply(lambda i: float(i[:4]) if isinstance(i, str) else i)

# %%
df["NoDoorNumbers"] =df["NoDoorNumbers"].apply(lambda i: int(i))

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7996 entries, 0 to 8368
# Data columns (total 31 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   city               7996 non-null   object
#  1   bt                 7996 non-null   object
#  2   km                 7996 non-null   int64
#  3   transmission       7996 non-null   object
#  4   ownerNo            7996 non-null   int64
#  5   oem                7996 non-null   object
#  6   modelYear          7996 non-null   int64
#  7   price              7897 non-null   float64
#  8   InsuranceValidity  7996 non-null   object
#  9   FuelType           7996 non-null   object
#  10  RTO                7996 non-null   object
#  11  Top_features       7996 non-null   int64
#  12  Mileage            7996 non-null   float64
#  13  Engine             7996 non-null   int64
#  14  Max_Power          7996 non-null   float64
#  15  Torque             7996 non-null   float64
#  16  Seats              7996 non-null   float64
#  17  Color              7996 non-null   object
#  18  NoofCylinder       7996 non-null   int64
#  19  ValuesperCylinder  7996 non-null   int64
#  20  TurboCharger       7996 non-null   object
#  21  Length             7996 non-null   float64
#  22  Width              7996 non-null   float64
#  23  Height             7996 non-null   float64
#  24  WheelBase          7996 non-null   float64
#  25  GearBox            7996 non-null   object
#  26  SteeringType       7996 non-null   object
#  27  FrontBrakeType     7996 non-null   object
#  28  RearBrakeType      7996 non-null   object
#  29  TyreType           7996 non-null   object
#  30  NoDoorNumbers      7996 non-null   int64
# dtypes: float64(9), int64(8), object(14)
# memory usage: 2.0+ MB

# %%
df.select_dtypes(include='object').columns
# Out:
# Index(['city', 'bt', 'transmission', 'oem', 'InsuranceValidity', 'FuelType',
#        'RTO', 'Color', 'TurboCharger', 'GearBox', 'SteeringType',
#        'FrontBrakeType', 'RearBrakeType', 'TyreType'],
#       dtype='object')

# %%
#spelling and word repetition/same meaning check
for i in df.select_dtypes(include='object').columns:
  print(i)
  print(df[i].unique())
  print("*****"*5)
# Out:
# city
# ['banglore' 'chennai' 'delhi' 'hyderabad' 'jaipur' 'kolkata']
# *************************
# bt
# ['Hatchback' 'SUV' 'Sedan' 'MUV' 'Coupe' 'Minivans' 'Convertibles'
#  'Hybrids' 'Wagon' 'Pickup Trucks']
# *************************
# transmission
# ['Manual' 'Automatic']
# *************************
# oem
# ['Maruti' 'Ford' 'Tata' 'Hyundai' 'Jeep' 'Datsun' 'Honda' 'Mahindra' 'BMW'
#  'Renault' 'Mercedes-Benz' 'Audi' 'Toyota' 'Mini' 'Kia' 'Skoda'
#  'Volkswagen' 'Volvo' 'MG' 'Nissan' 'Fiat' 'Mahindra Ssangyong'
#  'Mitsubishi' 'Jaguar' 'Land Rover' 'Chevrolet' 'Citroen' 'Opel'
#  'Mahindra Renault' 'Isuzu' 'Lexus' 'Porsche' 'Hindustan Motors']
# *************************
# InsuranceValidity
# ['Third Party insurance' 'Comprehensive' 'Third Party' 'Zero Dep' '2' '1'
#  'Not Available']
# *************************
# FuelType
# ['Petrol' 'Diesel' 'LPG' 'CNG' 'Electric']
# *************************
# RTO
# ['KA51' 'KA05' 'KA03' 'KA53' 'KA04' 'Unknown' 'KA01' 'OD02' 'KA41' 'KA02'
#  'HR26' 'WB38' 'KA47' 'KA19' 'KA50' 'KA09' 'PY01' 'KA66' 'KA20' 'KA52'
#  'KA25' 'KA27' 'TN09' 'KA13' 'MH46' 'KA42' 'KA12' 'KL07' 'KA55' 'KA07'
#  'KA17' 'KA16' 'TN33' 'KA06' 'KA22' 'KA14' 'KA35' 'KA21' 'KA32' 'KL24'
#  'KA63' 'KA26' 'KA11' 'KA36' 'KA40' 'DL14' 'UP32' 'KA34' 'KA45' 'AP39'
#  'DL8C' 'MH48' 'TN14' 'MH03' 'TN10' 'WB26' 'WB08' 'MH31' 'KL60' 'WB12'
#  'VK28' 'UP16' 'KL58' 'MP20' 'KA59' 'KA18' 'KA68' 'KA31' 'UP14' 'GJ06'
#  'UP70' 'DL03' 'AP28' 'HR51' 'RJ05' 'HR13' 'CH01' 'MH04' 'JH01' 'KA33'
#  'TS07' 'TN04' 'TN22' 'TN11' 'TN06' 'TN05' 'TN07' 'TN19' 'TN01' 'TN24'
#  'TN18' 'TN03' 'TN02' 'TN12' 'TN63' 'TN13' 'TN42' 'TN91' 'TN29' 'TN77'
#  'TN23' 'TN57' 'TN87' 'TN49' 'TN20' 'TN90' 'TN47' 'TN85' 'KL22' 'TN81'
#  'TN15' 'TN21' 'TN32' 'TN83' 'TN64' 'TN73' 'TN45' 'TN84' 'TN69' 'TN97'
#  'TN08' 'AP16' 'TN30' 'TN72' 'TN58' 'TN31' 'TN75' 'TN36' 'TN82' 'TN16'
#  'TN70' 'TN 0' 'TN48' 'TN38' 'TN 1' 'TN65' 'HP38' 'TN54' 'MH43' 'TN95'
#  'UP63' 'TN37' 'TN59' 'TN99' 'TN88' 'OR02' 'TN51' 'TN55' 'TN25' 'TN96'
#  'TN74' 'TN66' 'TN60' 'TM02' 'DL01' 'DL4C' 'DL9X' 'DL10' 'DL04' 'Up15'
#  'DL3C' 'DL2C' 'UP21' 'DL09' 'UK07' 'UP80' 'HR72' 'HR98' 'DL26' 'PH65'
#  'Hr22' 'UP15' 'DD4L' 'DL9C' 'GJ01' 'DL1C' 'DL6C' 'UP37' 'DL7C' 'DL5C'
#  'DL02' 'DL12' 'HR89' 'HR29' 'HR12' 'TS09' 'UK14' 'HR36' 'HP01' 'UP01'
#  'HR06' 'MH01' 'HR01' 'HR87' 'DL07' 'DL13' 'DL05' 'UK18' 'PB01' 'DL08'
#  'HP07' 'HR70' 'UP10' 'HR05' 'UP12' 'DL1Z' 'HR16' 'DD8L' 'MP30' 'HP12'
#  'DL86' 'HP34' 'HP52' 'DL11' 'PB70' 'DL3F' 'PY05' 'HR90' 'HR52' 'HP17'
#  'HR30' 'HP62' 'UK17' 'HR19' 'UP13' 'HP93' 'HR03' 'MH05' 'TS08' 'MH02'
#  'UP25' 'AS01' 'UP65' 'DL1V' 'DL5P' 'Dl12' 'DL1U' 'UP85' 'CG04' 'HR08'
#  'DL2B' 'DL9A' 'HP15' 'JH05' 'UP81' 'HR81' 'JH10' 'UP53' 'MP07' 'UK08'
#  'HR10' 'DL16' 'PB03' 'HR24' 'HR78' 'HP05' 'PB10' 'UK15' 'UK06' 'HR35'
#  'HR14' 'HR42' 'UP78' 'HP95' 'UP11' 'UP17' 'DL8A' 'PB87' 'MP04' 'DD06'
#  'TS04' 'TS32' 'AP10' 'TS15' 'TS22' 'TS13' 'TS11' 'TS28' 'TS30' 'TS10'
#  'TS27' 'TS16' 'TS17' 'TS05' 'TS23' 'TS06' 'AP11' 'AP26' 'TS12' 'TS35'
#  'AP04' 'TS33' 'TS03' 'TS25' 'AP13' 'AP22' 'TS31' 'AP07' 'TS29' 'AP09'
#  'TS02' 'AP29' 'TS19' 'AP20' 'TS34' 'AP36' 'TS36' 'AP31' 'TS24' 'AP23'
#  'TS01' 'AP21' 'AP05' 'GA03' 'TA13' 'AP24' 'AP12' 'AP27' 'TS21' 'TT07'
#  'MH14' 'KK04' 'WB02' 'TA10' 'AP25' 'TA07' 'AP02' 'AP01' 'AA28' 'MP09'
#  'GJ04' 'TS26' 'TT02' 'TS18' 'TN39' 'TD07' 'AP37' 'RJ13' 'RJ14' 'RJ32'
#  'RJ45' 'RJ19' 'RJ01' 'RJ27' 'RJ02' 'RJ37' '22BH' 'RJ22' 'RJ18' 'RJ23'
#  'RJ42' 'RJ48' 'RJ51' 'RJ40' 'HE26' 'RJ20' 'RJ16' 'RR23' 'RJ07' 'RJ21'
#  'MP17' 'RJ10' 'RJ29' 'RJ41' 'RJ36' 'RJ11' 'RJ44' 'RJ06' 'RJ26' 'RH14'
#  'RJ25' 'PB22' 'RJ31' 'GJ10' 'RJ34' 'RJ28' 'RJ39' 'RJ09' 'RJ04' 'RJ24'
#  'RJ53' 'PB65' 'RJ43' 'RJ12' 'RJ47' 'MP33' 'MH49' 'HR27' 'RJ30' 'RJ52'
#  'GJ14' 'R14C' 'RJ4G' 'UP72' 'HR43' 'MP13' 'BR3F' 'RJ35' 'MH18' 'UP64'
#  'UP82' 'WB24' 'WB06' 'WB18' 'WB22' 'WB20' 'WB10' 'WB96' 'WB92' 'UP33'
#  'AR01' 'WB36' 'WB42' 'WB16' 'WB40' 'WB34' 'WB74' 'WB98' 'OD33' 'WB44'
#  'WB52' 'AS05' 'Wb24' 'Wb10' 'WB14' 'WB32' 'WB50' 'WB94' 'Wb14' 'Wb26'
#  'Wb08' 'Wb06' 'HP47' 'Wb02' 'Wb12' 'Wb52' 'Wb16' 'wb02' 'Wb34' 'WB90'
#  'WB30' 'wb52' 'WW06' 'AN01' 'WB68' 'WB04' 'WB84' 'GJ15' 'WB60' 'WB66'
#  'WB05' 'wb24' 'wB24' 'WB03' 'BR01' 'wb06' 'WB58' 'AS04' 'WB72']
# *************************
# Color
# ['White' 'Red' 'Others' 'Gray' 'Grey' 'Maroon' 'Orange' 'Silver' 'Blue'
#  'Brown' 'Yellow' 'Black' 'Golden' 'Green' 'O Purple' 'Other' 'Gold'
#  'TITANIUM GREY' 'Violet' 'MODERN STEEL METALLIC' 'PLATINUM WHITE'
#  'Golden Brown' 'Aurora Black Pearl' 'Beige' 'Star Dust' 'Flash Red'
#  'Purple' 'PLATINUM WHITE PEARL' 'Wine Red' 'Taffeta White' 'Minimal Grey'
#  'Fiery Red' 'T Wine' 'Prime Star Gaze' 'TAFETA WHITE' 'P Black'
#  'Golden brown' 'METALL' 'MET ECRU BEIGE' 'COPPER' 'TITANIUM' 'CHILL'
#  'Burgundy' 'Lunar Silver Metallic' 'SILKY SILVER' 'BERRY RED'
#  'PREMIUM AMBER METALLIC' 'R EARTH' 'PLATINUM SILVER' 'ORCHID WHITE PEARL'
#  'CARNELIAN RED PEARL' 'POLAR WHITE' 'BEIGE' 'Medium Blue'
#  'Alabaster Silver Metallic' 'Carbon Steel' 'Cavern Grey' 'ESPRESO_BRWN'
#  'Pearl White' 'Polar White' 'Magma Grey' 'Dark Red' 'Falsa Colour'
#  'Cherry' 'Hip Hop Black' 'Nexa Blue' 'Passion Red' 'Cirrus White'
#  'Arizona Blue' 'Galaxy Blue' 'Silky Silver' 'Modern Steel Metal'
#  'GOLDEN BROWN' 'Burgundy Red Metallic' 'magma gray' 'CBeige'
#  'Goldan BRWOON' 'm grey' 'b red' 'Granite Grey' 'urban titanim' 'g brown'
#  'beige' 'Rosso Brunello' 'a silver' 'b grey' 'Radiant Red M' 'c bronze'
#  'Champagne Mica Metallic' 'Bold Beige Metallic' 'Sleek Silver'
#  'Symphony Silver' 'Phantom Black' 'Metallic Magma Grey' 'c brown' 'chill'
#  'Metallic Glistening Grey' 'Superior white' 'Modern Steel Metallic'
#  'Silky silver' 'Arctic Silver' 'Urban Titanium Metallic' 'Smoke Grey'
#  'Pearl Arctic White' 'Bright Silver' 'Porcelain White' 'Tafeta White'
#  'Coral White' 'Diamond White' 'Brick Red' 'Carnelian Red Pearl'
#  'Mediterranean Blue' 'Mist Silver' 'Gravity Gray' 'Candy White'
#  'Metallic Premium silver' 'Glistening Grey' 'Super white'
#  'Deep Black Pearl' 'Twilight Blue' 'Caviar Black'
#  'Pearl Met. Arctic White' 'Metallic silky silver' 'Pure white' 'StarDust'
#  'Alabaster Silver Metallic - Amaze' 'Ray blue' 'Glacier White Pearl'
#  'OUTBACK BRONZE' 'Solid Fire Red' 'Daytona Grey' 'Metallic Azure Grey'
#  'Moonlight Silver' 'Fire Brick Red' 'Cashmere' 'Pearl Snow White'
#  'Light Orange' 'Foliage' 'Sky Blue' 'Off White' 'Bronze' 'G Brown'
#  'Parpel' 'Outback Bronze' 'Cherry Red' 'Sunset Red' 'golden brown'
#  'Technometgrn+Gryroof' 'Dark Blue' 'Out Back Bronze']
# *************************
# TurboCharger
# ['No' 'Yes' 'Twin']
# *************************
# GearBox
# ['5 Speed ' '5 Speed' '6 Speed' '7-Speed' '4 Speed' '6 Speed ' '5-Speed'
#  '7 Speed' '9 Speed' '8 Speed' '8-Speed Steptronic' '6-Speed'
#  '7-Speed DCT' '8 Speed Tiptronic' '5' '6 Speed IMT' '6-speed AutoSHIFT'
#  '6-speed CVT' 'CVT' '6-speed' '7 Speed DSG' '7 Speed DCT' '6' '5-speed'
#  '6 speed ' '8-Speed Steptronic Sport Automatic Transmission' '5 speed'
#  '7 Speed CVT' 'Five Speed Manual' '5 Speed CVT' '6 Speed AT'
#  '6-Speed iMT' '7-Speed S-Tronic '
#  '7G DCT 7-Speed Dual Clutch Transmission ' '7-Speed S-Tronic' '5-Speed`'
#  '6-Speed IVT' 'Direct Drive' '6 Speed IVT' 'IVT' '8 Speed CVT' '8-Speed'
#  'Five Speed Manual Transmission' '5 Speed AT+ Paddle Shifters' '8-Speed '
#  'iMT' 'AGS' '6Speed' '4-Speed' '6-Speed IMT' '6 Speed MT' '7 Speed '
#  'Five Speed' '4 Speed ' '7-speed' '7-speed DCT' '7-Speed DSG'
#  'Six Speed Manual' '8 Speed Sport' '7-Speed Steptronic' '8' '6-Speed DCT'
#  '8-speed' 'Five Speed Manual Transmission Gearbox' 'E-CVT' '8 Speed '
#  '9 speed Tronic' '8 speed' '8-Speed Automatic Transmission' '9G-TRONIC'
#  'Six Speed Manual with Paddle Shifter' '7 Speed Steptronic Sport'
#  '4-speed' '6-speed DCT' '7 Speed 7G-DCT' '8Speed'
#  '8-speed Steptronic Automatic' '7-speed Stronic'
#  'Six Speed Automatic Transmission' '9G TRONIC' '5-Speed '
#  '7-Speed DCT Steptronic' '6-Speed AT' 'Mercedes Benz 7 Speed Automatic'
#  '10 speed' '7 speed' '6 speed automatic'
#  'Six Speed Geartronic, Six Speed Automati'
#  '5 Speed Manual (Cable Type Gear Shift)' 'Six Speed Automatic Gearbox'
#  '10 Speed' 'Six Speed  Gearbox' '7 Speed S tronic' '5 speed manual'
#  '7-Speed S tronic' '9-Speed' 'eCVT']
# *************************
# SteeringType
# ['Power' 'power' 'Electric' 'electric' 'EPAS' 'Electrical' 'Electronic'
#  'Manual']
# *************************
# FrontBrakeType
# ['Ventilated Disc' 'Disc' 'Disc ' ' Disc' 'Disc & Caliper Type'
#  'Ventilated discs' 'Ventilated Discs' 'Ventilated Disc '
#  'ventilated Disc' 'Disc, 236 mm' 'Multilateral Disc' 'Solid Disc' 'Disk'
#  'Drum' 'Electric Parking Brake' 'Ventilated DIsc' ' Ventilated Disc'
#  'Booster assisted ventilated disc' 'disc' 'Ventilated Disk'
#  'Vantilated Disc' 'ABS' 'Ventlated Disc' 'Caliper Ventilated Disc'
#  'solid disc' 'Disc,internally ventilated '
#  'Vacuum assisted hydraulic dual circuit w'
#  'Mechanical-hydraulic dual circuit' 'Ventillated Disc' 'ventilated disc'
#  'Ventilated disc' 'Discs' 'Tandem master cylinder with Servo assist'
#  'Disc brakes']
# *************************
# RearBrakeType
# ['Drum' 'Solid Disc' 'Discs' 'Disc & Caliper Type' 'Disc'
#  'Ventilated discs' 'Ventilated Disc' 'Leading-Trailing Drum'
#  'self adjusting drums' 'Self Adjusting Drum' 'Drums 180 mm' 'Drums'
#  'Self-Adjusting Drum' 'Ventilated Discs' 'Electric Parking Brake'
#  'Booster assisted drum' 'Leading & Trailing Drum' 'drum' 'Disc & Drum'
#  'Drum ' 'Ventilated Drum' 'Drum`' 'Ventilated Disc ' 'solid disc'
#  'Drum in Discs' 'Solid Disc ' 'Vacuum assisted hydraulic dual circuit w'
#  'Self Adjusting Drums' 'Mechanical-hydraulic dual circuit'
#  'Ventialte Disc' 'Drum in disc' '228.6 mm dia, drums on rear wheels']
# *************************
# TyreType
# ['Tubeless, Radial' 'Tubeless,Radial' 'Tubeless' 'Radial, Tubless'
#  'Radial' 'Tubeless,Radial ' 'Radial, Tubeless' 'Tubeless Radial Tyres'
#  'Tubeless Tyres' 'Tubeless,Runflat' 'Runflat Tyres' 'Run-Flat'
#  'Tubless, Radial' 'Runflat Tyre' 'Radial,Tubeless' 'Tubeless, Runflat'
#  'Tubeless Tyres, Radial' 'Runflat' 'Tubeless,Radials' 'Tubeless. Runflat'
#  'Tubless,Radial' 'Radial Tubeless' 'Tubeless Radial' 'tubeless tyre'
#  'Tubeless Tyre' 'Tubeless ' 'Radial Tyres' 'Tubeless Tyres Mud Terrain'
#  'Runflat,Radial' 'Tubeless Tyres All Terrain' 'Tubeless Radials Tyre'
#  'Radial ' 'Tubeless, Radials']
# *************************

# %%
#we dont knw what that 1 represents and it has only two value counts so we can drop that
df = df[df['InsuranceValidity'] != '1']
df = df[df['InsuranceValidity'] != '2']
df['InsuranceValidity'] = df['InsuranceValidity'].replace('Third Party', 'Third Party insurance')
df["InsuranceValidity"].value_counts()
# Out:
# InsuranceValidity
# Third Party insurance    4470
# Comprehensive            3010
# Zero Dep                  298
# Not Available             214
# Name: count, dtype: int64

# %%
def rto(value):
    if pd.isna(value):  # Check if the value is NaN
        return value
    else:
        return value[:-2].upper()
df["RTO"] = df["RTO"].apply(rto)
df["RTO"].unique()
# Out:
# array(['KA', 'UNKNO', 'OD', 'HR', 'WB', 'PY', 'TN', 'MH', 'KL', 'DL',
#        'UP', 'AP', 'VK', 'MP', 'GJ', 'RJ', 'CH', 'JH', 'TS', 'HP', 'OR',
#        'TM', 'UK', 'PH', 'DD', 'PB', 'AS', 'CG', 'GA', 'TA', 'TT', 'KK',
#        'AA', 'TD', '22', 'HE', 'RR', 'RH', 'R1', 'BR', 'AR', 'WW', 'AN'],
#       dtype=object)

# %%
#unwanted value 22 ans R1
df = df[df["RTO"] != "22"]
df = df[df["RTO"] != "R1"]

# %%
df['Color'] = df['Color'].str.lower().str.strip()

# %%
# Define a dictionary to map similar colors to a standard color
color_mapping = {
    'white': 'white','platinum white': 'white','platinum white pearl': 'white','taffeta white': 'white','superior white': 'white','pure white': 'white','polar white': 'white',
    'porcelain white': 'white','coral white': 'white','diamond white': 'white','pearl arctic white': 'white','pearl met. arctic white': 'white','super white': 'white',

    'red': 'red','flash red': 'red','fiery red': 'red','prime star gaze': 'red','b red': 'red','cherry red': 'red','fire brick red': 'red','passion red': 'red',

    'gray': 'gray','grey': 'gray','minimal grey': 'gray','urban titanium': 'gray','smoke grey': 'gray','gravity gray': 'gray','titanium grey': 'gray','daytona grey': 'gray',
    'metallic azure grey': 'gray','granite grey': 'gray',

    'blue': 'blue','nexa blue': 'blue','ray blue': 'blue','twilight blue': 'blue','sky blue': 'blue','mediterranean blue': 'blue','glacier white pearl': 'blue',
    'galaxy blue': 'blue','medium blue': 'blue',

    'black' : 'black','aurora black pearl': 'black','phantom black': 'black','caviar black': 'black','starry black': 'black',

    'silver': 'silver','light silver': 'silver','silky silver': 'silver','bright silver': 'silver','metallic premium silver': 'silver','arctic silver': 'silver','sleek silver': 'silver',

    'green': 'green','olive green': 'green',

    'golden': 'gold','gold': 'gold','golden brown': 'brown',

    'beige': 'beige','bold beige metallic': 'beige',

    'brown': 'brown','copper': 'brown','bronze': 'brown','espreso_brwn': 'brown',

    'others': 'others','other': 'others','falsa colour': 'others','metall': 'others','met ecru beige': 'others','champagne mica metallic': 'others','bold beige metallic': 'others',
    'carbon steel': 'others',
    "o purple":"purple","modern steel metallic":"others","beige":"white","star dust":"others",'wine red':'red','t wine':'others', 'tafeta white':'white',
    "p black":"black",'titanium':'others',"chill":"others","burgundy":"others","purple":"purple","lunar silver metallic":"silver",
    'berry red':'red','premium amber metallic':'others','r earth':'others','platinum silver':'silver', 'orchid white pearl':'white', 'carnelian red pearl':'red',
    'alabaster silver metallic':'silver','cavern grey':'gray', 'pearl white':'white','magma grey':'gray',
    'dark red':'red','cherry':'red','hip hop black':'black','cirrus white':'white','arizona blue':'blue',
    'modern steel metal':'others','burgundy red metallic':'red','magma gray':'gray','cbeige':'white','goldan brwoon':'brown','m grey':'gray',
    'urban titanim':'others','g brown':'brown','rosso brunello':'others','a silver':'silver','b grey':'gray', 'radiant red m':'red','c bronze':'others','metallic magma grey':'gray',
    'c brown':'brown','metallic glistening grey':'gray','urban titanium metallic':'others','violet':'purple','tafeta white':'white','carnelian red pearl':'red','brick red':'red',
    'mist silver':'silver','candy white':'white','glistening grey':'gray','deep black pearl':'black',
    'metallic silky silver':'silver', 'stardust':'others','alabaster silver metallic - amaze':'silver', 'outback bronze':'others','solid fire red':'red', 'moonlight silver':'silver',
    'cashmere':'others','pearl snow white':'white','light orange':'orange','foliage':'others', 'off white':'white','parpel':'others','sunset red':'red',
    'silicon silver':'silver','dark blue':'blue','technometgrn+gryroof':'others','out back bronze':'others','symphony silver':'silver'


}

# Apply the mapping to the color column
df['Color'] = df['Color'].replace(color_mapping)

df["Color"].unique()
# Out:
# array(['white', 'red', 'others', 'gray', 'maroon', 'orange', 'silver',
#        'blue', 'brown', 'yellow', 'black', 'gold', 'green', 'purple'],
#       dtype=object)

# %%
gearbox_mapping = {
    '5 Speed ':5, '5 Speed':5, '6 Speed':6, '7-Speed':7, '4 Speed':4, '6 Speed ':6,

       '8G-DCT':0, '5-Speed':5, '7 Speed':7, '9 Speed':9, '8 Speed':8,

       '8-Speed Steptronic':8, '6-Speed':6, '7-Speed DCT':7, '9-Speed':9,

       '8 Speed Tiptronic':8, '5':5, '6 Speed IMT':6, '6-speed AutoSHIFT':6,

       '6-speed CVT':6, 'CVT':0, '6-speed':6, '7-speed DCT':7, '7 Speed DSG':7,

       '7 Speed DCT':7, '6':6, '8-Speed':8, '5-speed':5, '6 speed ':6,

       '8-Speed Steptronic Sport Automatic Transmission':8, '5 speed':5,

       '7 Speed CVT':7, 'Five Speed Manual':5, '5 Speed CVT':5,

       '6 Speed AT':6, '6-Speed iMT':6, '6-Speed DCT':6, '7-Speed S-Tronic ':7,

       '7G DCT 7-Speed Dual Clutch Transmission ':7, '7-Speed S-Tronic':7,

       '5-Speed`':5, '9 speed Tronic':9, '6-Speed IVT':6, 'Direct Drive':0,

       '6 Speed IVT':6, 'IVT':0, '8 Speed CVT':8,

       'Five Speed Manual Transmission':5, '5 Speed AT+ Paddle Shifters':5,

       '8-Speed ':8, 'iMT':0, 'AGS':0, '6Speed':6, '4-Speed':4, '6-Speed IMT':6,

       '6 Speed MT':6, '6 Speed iMT':6, '7 Speed ':7, 'Five Speed':5, '4 Speed ':4,

       '7-speed':7, '6-Speed AT':6, '9G-TRONIC':0, '9G-TRONIC automatic':0,

       '7-Speed DSG':7, 'Six Speed Manual':6, '8 Speed Sport':8,

       '6 Speed with Sequential Shift':6, '6-speed IVT':6,

       '7-Speed Steptronic':7, '8':8, '8-speed':8,

       'Five Speed Manual Transmission Gearbox':5, 'AMG SPEEDSHIFT DCT 8G':0,

       'AMG 7-SPEED DCT':7, 'E-CVT':0, '8 Speed ':8, '7-speed Stronic':7,

       '8 speed':8, '8-Speed Automatic Transmission':8,

       'Six Speed Manual with Paddle Shifter':6, '7 Speed Steptronic Sport':7,

       '4-speed':4, '6-speed DCT':6, '9-speed automatic':9, 'SPEEDSHIFT TCT 9G':0,

       '7 Speed 7G-DCT':7, '7-speed PDK':7, '8Speed':8,

       '8-speed Steptronic Automatic':8, '10-speed Automatic':10,

       'Six Speed Automatic Transmission':6, '9G TRONIC':0, '5-Speed ':5,


       '7-Speed DCT Steptronic':7, '8-Speed DCT':8,

       'Mercedes Benz 7 Speed Automatic':7, '10 speed':10, '6-speed iMT':6,

       '7 speed':7, '6 speed automatic':6, '7G-DCT':0,

       'Six Speed Geartronic, Six Speed Automati':6,

       '5 Speed Manual (Cable Type Gear Shift)':5,

       'Six Speed Automatic Gearbox':6, '10 Speed':10, 'Fully Automatic':0,

       'Single-speed transmission':0, 'Six Speed  Gearbox':6,

       '5 Speed Forward, 1 Reverse':5, '7 Speed S tronic':7,

       'Single speed reduction gear':0, 'Single Speed':0, '5 speed manual':5,

       '9 -speed':9, '8-speed tiptronic':8, '7-Speed S tronic':7, 'eCVT':0
}

df["GearBox"] = df["GearBox"].replace(gearbox_mapping)
df["GearBox"].unique()
# Out:
# C:\Users\shank\AppData\Local\Temp\ipykernel_6180\2325760734.py:78: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["GearBox"] = df["GearBox"].replace(gearbox_mapping)
# array([ 5,  6,  7,  4,  9,  8,  0, 10], dtype=int64)

# %%
df["SteeringType"] =df["SteeringType"].replace({'power':'Power',"electric":"Electric",'Electrical':"Electric", 'Electronic':"Electric"})
df["SteeringType"].unique()
# Out:
# array(['Power', 'Electric', 'EPAS', 'Manual'], dtype=object)

# %%
brake_type_mapping = {
    'ventilated disc': 'Ventilated Disc','ventilated discs': 'Ventilated Disc','ventilated disk': 'Ventilated Disc','ventilated disc': 'Ventilated Disc',
    'booster assisted ventilated disc': 'Ventilated Disc','caliper ventilated disc': 'Ventilated Disc',  'disc,internally ventilated': 'Ventilated Disc',
    'vantilated disc': 'Ventilated Disc',  'ventillated disc': 'Ventilated Disc',  'ventilated Disc':'Ventilated Disc',
   'Ventilated Discs':'Ventilated Disc','Ventilated Disc ':'Ventilated Disc', 'Ventilated DIsc':'Ventilated Disc','Booster assisted ventilated disc':'Ventilated Disc',
    'Ventilated Disk':'Ventilated Disc','Vantilated Disc':'Ventilated Disc','Ventlated Disc':'Ventilated Disc','Caliper Ventilated Disc':'Ventilated Disc',
    'Disc,internally ventilated ' :'Ventilated Disc','Ventillated Disc':'Ventilated Disc','ventilated disc':'Ventilated Disc','Ventilated disc':'Ventilated Disc',

    'disc': 'Disc','disc & caliper type': 'Disc','multilateral disc': 'Disc','disc brakes': 'Disc','solid disc': 'Disc', 'disc, 236 mm': 'Disc',
    'Disc ':'Disc', ' Disc':'Disc','disk': 'Disc',  'discs': 'Disc', 'Disk':'Disc', 'Discs':'Disc','Disc brakes':'Disc', 'Disc & Caliper Type':'Disc',
      # Also covers variations
    'electric parking brake': 'Others',

    'abs': 'Others','mechanical-hydraulic dual circuit': 'Others','ABS':'others',
    'vacuum assisted hydraulic dual circuit w': 'Others','Mechanical-hydraulic dual circuit':'others',
    'tandem master cylinder with servo assist': 'Others','Tandem master cylinder with Servo assist':'others',

    'drum': 'Drum','ventlated disc':'Ventilated Disc'
      # Similar to 'disc'

}
df['FrontBrakeType'] = df['FrontBrakeType'].replace(brake_type_mapping)
df["FrontBrakeType"].unique()
# Out:
# array(['Ventilated Disc', 'Disc', 'Ventilated discs', 'Disc, 236 mm',
#        'Multilateral Disc', 'Solid Disc', 'Drum',
#        'Electric Parking Brake', ' Ventilated Disc', 'others',
#        'Vacuum assisted hydraulic dual circuit w'], dtype=object)

# %%
df['FrontBrakeType'] =df['FrontBrakeType'].replace({'Ventilated discs':'Disc','Disc, 236 mm':'Disc','Multilateral Disc':'Disc', 'Solid Disc':'Disc',
                                                    'Electric Parking Brake':'others','Ventilated Disc':'Disc',' Ventilated Disc':'Disc','Vacuum assisted hydraulic dual circuit w':'others'})

# %%
df["FrontBrakeType"].unique()
# Out:
# array(['Disc', 'Drum', 'others'], dtype=object)

# %%
df['RearBrakeType'] = df['RearBrakeType'].str.strip().str.lower()

brake_type_mapping1 = {
    'ventilated disc': 'Ventilated Disc','ventilated discs': 'Ventilated Disc',

    'ventilated drum': 'Ventilated Drum',
    'self adjusting drums': 'Drum',
    'self adjusting drum': 'Drum',
    'self-adjusting drum': 'Drum',
    'drums': 'Drum',
    'leading-trailing drum': 'Drum',
    'leading & trailing drum': 'Drum',
    'drum': 'Drum',
    'drum in disc': 'Drum in Disc',
    'disc': 'Disc',
    'disc & caliper type': 'Disc',
    'solid disc': 'Disc',
    'disc & drum': 'Disc & Drum',
    'electric parking brake': 'Others',
    'booster assisted drum': 'Drum',
    'vacuum assisted hydraulic dual circuit w': 'Others',
    'mechanical-hydraulic dual circuit': 'Others',
    'ventialte disc': 'Ventilated Disc',
    'disc, 236 mm': 'Disc',
    'drum `': 'Drum',
    'solid disc ': 'Disc',
    '228.6 mm dia, drums on rear wheels': 'Drum'
}

df['RearBrakeType'] = df['RearBrakeType'].replace(brake_type_mapping1)
df["RearBrakeType"].unique()
# Out:
# array(['Drum', 'Disc', 'discs', 'Ventilated Disc', 'drums 180 mm',
#        'Others', 'Disc & Drum', 'Ventilated Drum', 'drum`',
#        'drum in discs', 'Drum in Disc'], dtype=object)

# %%
df['RearBrakeType'] = df['RearBrakeType'].replace({'discs':'Disc', 'drums 180 mm':'Drum', 'drum`':'Drum','drum in discs':'Others','Ventilated Disc':'Disc',
                                                  'Disc & Drum':'Others', 'Ventilated Drum':'Drum','Drum in Disc':'Others' })
df["RearBrakeType"].unique()
# Out:
# array(['Drum', 'Disc', 'Others'], dtype=object)

# %%
df.drop("TyreType",axis=1,inplace=True)

# %%
#spelling and word repetition/same meaning check
for i in df.select_dtypes(include='object').columns:
  print(i)
  print(df[i].unique())
  print("*****"*5)
# Out:
# city
# ['banglore' 'chennai' 'delhi' 'hyderabad' 'jaipur' 'kolkata']
# *************************
# bt
# ['Hatchback' 'SUV' 'Sedan' 'MUV' 'Coupe' 'Minivans' 'Convertibles'
#  'Hybrids' 'Wagon' 'Pickup Trucks']
# *************************
# transmission
# ['Manual' 'Automatic']
# *************************
# oem
# ['Maruti' 'Ford' 'Tata' 'Hyundai' 'Jeep' 'Datsun' 'Honda' 'Mahindra' 'BMW'
#  'Renault' 'Mercedes-Benz' 'Audi' 'Toyota' 'Mini' 'Kia' 'Skoda'
#  'Volkswagen' 'Volvo' 'MG' 'Nissan' 'Fiat' 'Mahindra Ssangyong'
#  'Mitsubishi' 'Jaguar' 'Land Rover' 'Chevrolet' 'Citroen' 'Opel'
#  'Mahindra Renault' 'Isuzu' 'Lexus' 'Porsche' 'Hindustan Motors']
# *************************
# InsuranceValidity
# ['Third Party insurance' 'Comprehensive' 'Zero Dep' 'Not Available']
# *************************
# FuelType
# ['Petrol' 'Diesel' 'LPG' 'CNG' 'Electric']
# *************************
# RTO
# ['KA' 'UNKNO' 'OD' 'HR' 'WB' 'PY' 'TN' 'MH' 'KL' 'DL' 'UP' 'AP' 'VK' 'MP'
#  'GJ' 'RJ' 'CH' 'JH' 'TS' 'HP' 'OR' 'TM' 'UK' 'PH' 'DD' 'PB' 'AS' 'CG'
#  'GA' 'TA' 'TT' 'KK' 'AA' 'TD' 'HE' 'RR' 'RH' 'BR' 'AR' 'WW' 'AN']
# *************************
# Color
# ['white' 'red' 'others' 'gray' 'maroon' 'orange' 'silver' 'blue' 'brown'
#  'yellow' 'black' 'gold' 'green' 'purple']
# *************************
# TurboCharger
# ['No' 'Yes' 'Twin']
# *************************
# SteeringType
# ['Power' 'Electric' 'EPAS' 'Manual']
# *************************
# FrontBrakeType
# ['Disc' 'Drum' 'others']
# *************************
# RearBrakeType
# ['Drum' 'Disc' 'Others']
# *************************

# %%
df.head()
# Out:
#        city         bt      km transmission  ownerNo      oem  modelYear  \
# 0  banglore  Hatchback  120000       Manual        3   Maruti       2015
# 1  banglore        SUV   32706       Manual        2     Ford       2018
# 2  banglore  Hatchback   11949       Manual        1     Tata       2018
# 3  banglore      Sedan   17794       Manual        1  Hyundai       2014
# 4  banglore        SUV   60000       Manual        1   Maruti       2015
#
#       price      InsuranceValidity FuelType RTO  Top_features  Mileage  \
# 0  400000.0  Third Party insurance   Petrol  KA             8    23.10
# 1  811000.0          Comprehensive   Petrol  KA             9    17.00
# 2  585000.0          Comprehensive   Petrol  KA             9    23.84
# 3  462000.0          Comprehensive   Petrol  KA             9    19.10
# 4  790000.0  Third Party insurance   Diesel  KA             9    23.65
#
#    Engine  Max_Power  Torque  Seats   Color  NoofCylinder  ValuesperCylinder  \
# 0     998      67.04   90.00    5.0   white             3                  4
# 1    1497     121.31  150.00    5.0   white             3                  4
# 2    1199      84.00  114.00    5.0     red             3                  4
# 3    1197      81.86  113.75    5.0  others             4                  4
# 4    1248      88.50  200.00    5.0    gray             4                  4
#
#   TurboCharger  Length   Width  Height  WheelBase  GearBox SteeringType  \
# 0           No  3715.0  1635.0  1565.0     2425.0        5        Power
# 1           No  3998.0  1765.0  1647.0     2519.0        5        Power
# 2           No  3746.0  1647.0  1535.0     2400.0        5        Power
# 3           No  3995.0  1660.0  1520.0     2425.0        5        Power
# 4          Yes  4300.0  1785.0  1595.0     2600.0        5        Power
#
#   FrontBrakeType RearBrakeType  NoDoorNumbers
# 0           Disc          Drum              5
# 1           Disc          Drum              4
# 2           Disc          Drum              5
# 3           Disc          Drum              4
# 4           Disc          Disc              5

# %%
pip install scikit-learn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: scikit-learn in c:\users\shank\appdata\roaming\python\python312\site-packages (1.5.2)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\shank\appdata\roaming\python\python312\site-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\shank\appdata\roaming\python\python312\site-packages (from scikit-learn) (1.14.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\shank\appdata\roaming\python\python312\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\shank\appdata\roaming\python\python312\site-packages (from scikit-learn) (3.5.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Outlier

# %%
cont = []
cat = []
for i in df.columns:
  if df[i].nunique()>41:
    cont.append(i)
  else:
    cat.append(i)

print(cont,cat)

# %%
df.shape

# %%
def remove_outliers(df, columns):
    for col in columns:
        Q1 = df[col].quantile(0.25)
        Q3 = df[col].quantile(0.75)
        IQR = Q3 - Q1
        df = df[(df[col] >= (Q1 - 1.5 * IQR)) & (df[col] <= (Q3 + 1.5 * IQR))]
    return df

# Apply outlier removal
df = remove_outliers(df, cont)

print(df.shape)

# %% [markdown]
# # encoding

# %%
from sklearn.preprocessing import LabelEncoder
import pickle

# %%
#encoding
encoders = {}
for column in df.select_dtypes(include='object').columns:
    encoder = LabelEncoder()
    df[column] = encoder.fit_transform(df[column])
    encoders[column] = encoder

with open('label_encoders.pkl', 'wb') as f:
    pickle.dump(encoders, f)

# %%
df.head()
# Out:
#    city  bt      km  transmission  ownerNo  oem  modelYear     price  \
# 0     0   2  120000             1        3   20       2015  400000.0
# 1     0   7   32706             1        2    6       2018  811000.0
# 2     0   2   11949             1        1   29       2018  585000.0
# 3     0   8   17794             1        1    9       2014  462000.0
# 4     0   7   60000             1        1   20       2015  790000.0
#
#    InsuranceValidity  FuelType  RTO  Top_features  Mileage  Engine  Max_Power  \
# 0                  2         4   16             8    23.10     998      67.04
# 1                  0         4   16             9    17.00    1497     121.31
# 2                  0         4   16             9    23.84    1199      84.00
# 3                  0         4   16             9    19.10    1197      81.86
# 4                  2         1   16             9    23.65    1248      88.50
#
#    Torque  Seats  Color  NoofCylinder  ValuesperCylinder  TurboCharger  \
# 0   90.00    5.0     12             3                  4             0
# 1  150.00    5.0     12             3                  4             0
# 2  114.00    5.0     10             3                  4             0
# 3  113.75    5.0      8             4                  4             0
# 4  200.00    5.0      4             4                  4             2
#
#    Length   Width  Height  WheelBase  GearBox  SteeringType  FrontBrakeType  \
# 0  3715.0  1635.0  1565.0     2425.0        5             3               0
# 1  3998.0  1765.0  1647.0     2519.0        5             3               0
# 2  3746.0  1647.0  1535.0     2400.0        5             3               0
# 3  3995.0  1660.0  1520.0     2425.0        5             3               0
# 4  4300.0  1785.0  1595.0     2600.0        5             3               0
#
#    RearBrakeType  NoDoorNumbers
# 0              1              5
# 1              1              4
# 2              1              5
# 3              1              4
# 4              0              5

# %%
for i in df.columns:
  print(i,df[i].nunique())
# Out:
# city 6
# bt 10
# km 4000
# transmission 2
# ownerNo 6
# oem 33
# modelYear 28
# price 1303
# InsuranceValidity 4
# FuelType 5
# RTO 41
# Top_features 8
# Mileage 516
# Engine 142
# Max_Power 437
# Torque 264
# Seats 8
# Color 14
# NoofCylinder 8
# ValuesperCylinder 5
# TurboCharger 3
# Length 320
# Width 212
# Height 234
# WheelBase 173
# GearBox 8
# SteeringType 4
# FrontBrakeType 3
# RearBrakeType 3
# NoDoorNumbers 5

# %% [markdown]
# # EDA

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Scatter plot of Mileage vs. Price
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='Mileage', y='price', hue='FuelType')
plt.title('Mileage vs. Price')
plt.xlabel('Mileage')
plt.ylabel('Price')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['price'], kde=True)
plt.title('Distribution of Car Prices')
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='FuelType', y='price', data=df)
plt.title('Price Distribution by Fuel Type')
plt.xlabel('Fuel Type')
plt.ylabel('Price')
plt.show()

# %%
for feature in cont:
    plt.figure(figsize=(8, 4))
    sns.histplot(df[feature], kde=True, bins=30, color='blue')
    plt.title(f'Distribution of {feature}')
    plt.xlabel(feature)
    plt.ylabel('Frequency')
    plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='ownerNo', y='price', data=df, palette='Reds_d')
plt.title('Average Price by Number of Owners')
plt.show()
# Out:
# C:\Users\shank\AppData\Local\Temp\ipykernel_6180\4029691544.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='ownerNo', y='price', data=df, palette='Reds_d')

# %% [markdown]
# # corr

# %%
cont.append('price')

# %%
#correlation checking - corr value should be nearer to 1 or -1
#if its nearer to 1/-1 then there is some connectivity between those two columns

corr_matrix =df[cont].corr()
corr_matrix
# Out:
#                  km     price   Mileage    Engine  Max_Power    Torque  \
# km         1.000000 -0.335814  0.120454  0.220222  -0.059489  0.272291
# price     -0.335814  1.000000 -0.165180  0.239915   0.541690  0.312040
# Mileage    0.120454 -0.165180  1.000000 -0.260956  -0.454050  0.124276
# Engine     0.220222  0.239915 -0.260956  1.000000   0.653378  0.601525
# Max_Power -0.059489  0.541690 -0.454050  0.653378   1.000000  0.550016
# Torque     0.272291  0.312040  0.124276  0.601525   0.550016  1.000000
# Length     0.076880  0.478468 -0.338833  0.652635   0.698136  0.526448
# Width     -0.008726  0.604525 -0.239369  0.571345   0.732572  0.559415
# Height    -0.071502  0.349146 -0.102479  0.245246   0.415499  0.306317
# WheelBase -0.032456  0.544443 -0.303768  0.501333   0.621500  0.440815
# price     -0.335814  1.000000 -0.165180  0.239915   0.541690  0.312040
#
#              Length     Width    Height  WheelBase     price
# km         0.076880 -0.008726 -0.071502  -0.032456 -0.335814
# price      0.478468  0.604525  0.349146   0.544443  1.000000
# Mileage   -0.338833 -0.239369 -0.102479  -0.303768 -0.165180
# Engine     0.652635  0.571345  0.245246   0.501333  0.239915
# Max_Power  0.698136  0.732572  0.415499   0.621500  0.541690
# Torque     0.526448  0.559415  0.306317   0.440815  0.312040
# Length     1.000000  0.766735  0.163410   0.800834  0.478468
# Width      0.766735  1.000000  0.404295   0.734375  0.604525
# Height     0.163410  0.404295  1.000000   0.225472  0.349146
# WheelBase  0.800834  0.734375  0.225472   1.000000  0.544443
# price      0.478468  0.604525  0.349146   0.544443  1.000000

# %%
#km - it has least linear relationship with other columns 
#milege - this column has good linear relationship with other columns, has strong negative relationship with engine,max_poer,length
#engine - this column has strong linear relationship with other columns except km, it has very strong +ve relationship with length column
#max_power - it has very strong +ve corr between length,width, wheelbase
#torque - it has very strong +ve corr between max_power, length,width, wheelbase
#like that length, width,height column is also have strng relationship with other columns except km col
#cargovolumne - least relationship between km and height
#price has good relationship with others

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Correlation Matrix of Features')
plt.show()

# %% [markdown]
# # ML

# %%
X = df.drop("price",axis=1)
y = df["price"]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test =train_test_split(X,y,test_size=0.25)

# %%
from sklearn.preprocessing import StandardScaler

# Initialize the scaler

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)

with open('scaler.pkl', 'wb') as f:
    pickle.dump(scaler, f)

X_test_scaled = scaler.transform(X_test)

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression().fit(X_train_scaled,y_train)
y_pred=model.predict(X_test_scaled)
print(mean_squared_error(y_test,y_pred))
print(mean_absolute_error(y_test,y_pred))
print(r2_score(y_test,y_pred))
# Out:
# 20685878462.89408
# 81493.50249981474
# 0.6306661559878927

# %%
from sklearn.ensemble import RandomForestRegressor
model = RandomForestRegressor().fit(X_train_scaled,y_train)
y_pred=model.predict(X_test_scaled)
print(mean_squared_error(y_test,y_pred))
print(mean_absolute_error(y_test,y_pred))
print(r2_score(y_test,y_pred))
# Out:
# 16206650399.438002
# 64375.68230749746
# 0.7106400629143327

# %%
# !pip install xgboost
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: xgboost in c:\users\shank\appdata\roaming\python\python312\site-packages (2.1.1)
# Requirement already satisfied: numpy in c:\users\shank\appdata\roaming\python\python312\site-packages (from xgboost) (1.26.4)
# Requirement already satisfied: scipy in c:\users\shank\appdata\roaming\python\python312\site-packages (from xgboost) (1.14.1)

# %%
from xgboost import XGBRegressor
model = XGBRegressor().fit(X_train_scaled,y_train)
y_pred=model.predict(X_test_scaled)
print(mean_squared_error(y_test,y_pred))
print(mean_absolute_error(y_test,y_pred))
print(r2_score(y_test,y_pred))
# Out:
# 18623307811.148907
# 66106.10762272828
# 0.6674921070212058

# %%
from sklearn.ensemble  import GradientBoostingRegressor
model = GradientBoostingRegressor().fit(X_train_scaled,y_train)
y_pred=model.predict(X_test_scaled)
print(mean_squared_error(y_test,y_pred))
print(mean_absolute_error(y_test,y_pred))
print(r2_score(y_test,y_pred))
# Out:
# 16670250634.78012
# 64607.676136806396
# 0.702362761212548

# %%
from sklearn.ensemble import RandomForestRegressor
model = RandomForestRegressor().fit(X_train_scaled,y_train)
y_pred=model.predict(X_test_scaled)
print(mean_squared_error(y_test,y_pred))
print(mean_absolute_error(y_test,y_pred))
print(r2_score(y_test,y_pred))
# Out:
# 16385455275.27213
# 64552.87687858831
# 0.7074476100417905

# %%
#from the above the model we can go with  randomforest
#hypertuning
from sklearn.model_selection import GridSearchCV

param_grid = {'n_estimators': [100, 200,300], 'max_depth': [10, 20,30,40, None]}
grid_search = GridSearchCV(estimator=model, param_grid=param_grid, cv=5)

grid_search.fit(X_train, y_train)
best_model = grid_search.best_estimator_
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[98], line 8
#       5 param_grid = {'n_estimators': [100, 200,300], 'max_depth': [10, 20,30,40, None]}
#       6 grid_search = GridSearchCV(estimator=model, param_grid=param_grid, cv=5)
# ----> 8 grid_search.fit(X_train, y_train)
#       9 best_model = grid_search.best_estimator_
#
# File ~\AppData\Roaming\Python\Python312\site-packages\sklearn\base.py:1473, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1466     estimator._validate_params()
#    1468 with config_context(
#    1469     skip_parameter_validation=(
#    1470         prefer_skip_nested_validation or global_skip_validation
#    1471     )
#    1472 ):
# -> 1473     return fit_method(estimator, *args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\sklearn\model_selection\_search.py:1019, in BaseSearchCV.fit(self, X, y, **params)
#    1013     results = self._format_results(
#    1014         all_candidate_params, n_splits, all_out, all_more_results
#    1015     )
#    1017     return results
# -> 1019 self._run_search(evaluate_candidates)
#    1021 # multimetric is determined here because in the case of a callable
#    1022 # self.scoring the return type is only known after calling
#    1023 first_test_score = all_out[0]["test_scores"]
#
# File ~\AppData\Roaming\Python\Python312\site-packages\sklearn\model_selection\_search.py:1573, in GridSearchCV._run_search(self, evaluate_candidates)
#    1571 def _run_search(self, evaluate_candidates):
#    1572     """Search all candidates in param_grid"""
# -> 1573     evaluate_candidates(ParameterGrid(self.param_grid))
#
# File ~\AppData\Roaming\Python\Python312\site-packages\sklearn\model_selection\_search.py:965, in BaseSearchCV.fit.<locals>.evaluate_candidates(candidate_params, cv, more_results)
#     957 if self.verbose > 0:
#     958     print(
#     959         "Fitting {0} folds for each of {1} candidates,"
#     960         " totalling {2} fits".format(
#     961             n_splits, n_candidates, n_candidates * n_splits
#     962         )
#     963     )
# --> 965 out = parallel(
#     966     delayed(_fit_and_score)(
#     967         clone(base_estimator),
#     968         X,
#     969         y,
#     970         train=train,
#     971         test=test,
#     972         parameters=parameters,
#     973         split_progress=(split_idx, n_splits),
#     974         candidate_progress=(cand_idx, n_candidates),
#     975         **fit_and_score_kwargs,
#     976     )
#     977     for (cand_idx, parameters), (split_idx, (train, test)) in product(
#     978         enumerate(candidate_params),
#     979         enumerate(cv.split(X, y, **routed_params.splitter.split)),
#     980     )
#     981 )
#     983 if len(out) < 1:
#     984     raise ValueError(
#     985         "No fits were performed. "
#     986         "Was the CV iterator empty? "
#     987         "Were there no candidates?"
#     988     )
#
# File ~\AppData\Roaming\Python\Python312\site-packages\sklearn\utils\parallel.py:74, in Parallel.__call__(self, iterable)
#      69 config = get_config()
#      70 iterable_with_config = (
#      71     (_with_config(delayed_func, config), args, kwargs)
#      72     for delayed_func, args, kwargs in iterable
#      73 )
# ---> 74 return super().__call__(iterable_with_config)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\joblib\parallel.py:1918, in Parallel.__call__(self, iterable)
#    1916     output = self._get_sequential_output(iterable)
#    1917     next(output)
# -> 1918     return output if self.return_generator else list(output)
#    1920 # Let's create an ID that uniquely identifies the current call. If the
#    1921 # call is interrupted early and that the same instance is immediately
#    1922 # re-used, this id will be used to prevent workers that were
#    1923 # concurrently finalizing a task from the previous call to run the
#    1924 # callback.
#    1925 with self._lock:
#
# File ~\AppData\Roaming\Python\Python312\site-packages\joblib\parallel.py:1847, in Parallel._get_sequential_output(self, iterable)
#    1845 self.n_dispatched_batches += 1
#    1846 self.n_dispatched_tasks += 1
# -> 1847 res = func(*args, **kwargs)
#    1848 self.n_completed_tasks += 1
#    1849 self.print_progress()
#
# File ~\AppData\Roaming\Python\Python312\site-packages\sklearn\utils\parallel.py:136, in _FuncWrapper.__call__(self, *args, **kwargs)
#     134     config = {}
#     135 with config_context(**config):
# --> 136     return self.function(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\sklearn\model_selection\_validation.py:888, in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, score_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, split_progress, candidate_progress, error_score)
#     886         estimator.fit(X_train, **fit_params)
#     887     else:
# --> 888         estimator.fit(X_train, y_train, **fit_params)
#     890 except Exception:
#     891     # Note fit time as time until error
#     892     fit_time = time.time() - start_time
#
# File ~\AppData\Roaming\Python\Python312\site-packages\sklearn\base.py:1473, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1466     estimator._validate_params()
#    1468 with config_context(
#    1469     skip_parameter_validation=(
#    1470         prefer_skip_nested_validation or global_skip_validation
#    1471     )
#    1472 ):
# -> 1473     return fit_method(estimator, *args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\sklearn\ensemble\_forest.py:489, in BaseForest.fit(self, X, y, sample_weight)
#     478 trees = [
#     479     self._make_estimator(append=False, random_state=random_state)
#     480     for i in range(n_more_estimators)
#     481 ]
#     483 # Parallel loop: we prefer the threading backend as the Cython code
#     484 # for fitting the trees is internally releasing the Python GIL
#     485 # making threading more efficient than multiprocessing in
#     486 # that case. However, for joblib 0.12+ we respect any
#     487 # parallel_backend contexts set at a higher level,
#     488 # since correctness does not rely on using threads.
# --> 489 trees = Parallel(
#     490     n_jobs=self.n_jobs,
#     491     verbose=self.verbose,
#     492     prefer="threads",
#     493 )(
#     494     delayed(_parallel_build_trees)(
#     495         t,
#     496         self.bootstrap,
#     497         X,
#     498         y,
#     499         sample_weight,
#     500         i,
#     501         len(trees),
#     502         verbose=self.verbose,
#     503         class_weight=self.class_weight,
#     504         n_samples_bootstrap=n_samples_bootstrap,
#     505         missing_values_in_feature_mask=missing_values_in_feature_mask,
#     506     )
#     507     for i, t in enumerate(trees)
#     508 )
#     510 # Collect newly grown trees
#     511 self.estimators_.extend(trees)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\sklearn\utils\parallel.py:74, in Parallel.__call__(self, iterable)
#      69 config = get_config()
#      70 iterable_with_config = (
#      71     (_with_config(delayed_func, config), args, kwargs)
#      72     for delayed_func, args, kwargs in iterable
#      73 )
# ---> 74 return super().__call__(iterable_with_config)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\joblib\parallel.py:1918, in Parallel.__call__(self, iterable)
#    1916     output = self._get_sequential_output(iterable)
#    1917     next(output)
# -> 1918     return output if self.return_generator else list(output)
#    1920 # Let's create an ID that uniquely identifies the current call. If the
#    1921 # call is interrupted early and that the same instance is immediately
#    1922 # re-used, this id will be used to prevent workers that were
#    1923 # concurrently finalizing a task from the previous call to run the
#    1924 # callback.
#    1925 with self._lock:
#
# File ~\AppData\Roaming\Python\Python312\site-packages\joblib\parallel.py:1847, in Parallel._get_sequential_output(self, iterable)
#    1845 self.n_dispatched_batches += 1
#    1846 self.n_dispatched_tasks += 1
# -> 1847 res = func(*args, **kwargs)
#    1848 self.n_completed_tasks += 1
#    1849 self.print_progress()
#
# File ~\AppData\Roaming\Python\Python312\site-packages\sklearn\utils\parallel.py:136, in _FuncWrapper.__call__(self, *args, **kwargs)
#     134     config = {}
#     135 with config_context(**config):
# --> 136     return self.function(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\sklearn\ensemble\_forest.py:192, in _parallel_build_trees(tree, bootstrap, X, y, sample_weight, tree_idx, n_trees, verbose, class_weight, n_samples_bootstrap, missing_values_in_feature_mask)
#     189     elif class_weight == "balanced_subsample":
#     190         curr_sample_weight *= compute_sample_weight("balanced", y, indices=indices)
# --> 192     tree._fit(
#     193         X,
#     194         y,
#     195         sample_weight=curr_sample_weight,
#     196         check_input=False,
#     197         missing_values_in_feature_mask=missing_values_in_feature_mask,
#     198     )
#     199 else:
#     200     tree._fit(
#     201         X,
#     202         y,
#    (...)
#     205         missing_values_in_feature_mask=missing_values_in_feature_mask,
#     206     )
#
# File ~\AppData\Roaming\Python\Python312\site-packages\sklearn\tree\_classes.py:472, in BaseDecisionTree._fit(self, X, y, sample_weight, check_input, missing_values_in_feature_mask)
#     461 else:
#     462     builder = BestFirstTreeBuilder(
#     463         splitter,
#     464         min_samples_split,
#    (...)
#     469         self.min_impurity_decrease,
#     470     )
# --> 472 builder.build(self.tree_, X, y, sample_weight, missing_values_in_feature_mask)
#     474 if self.n_outputs_ == 1 and is_classifier(self):
#     475     self.n_classes_ = self.n_classes_[0]
#
# KeyboardInterrupt:

# %%
best_model
# Out:
# RandomForestRegressor(max_depth=20, n_estimators=200)

# %%
from sklearn.ensemble import RandomForestRegressor
model = RandomForestRegressor(max_depth=20, n_estimators=200).fit(X_train_scaled,y_train)
y_pred=model.predict(X_test_scaled)
print(mean_squared_error(y_test,y_pred))
print(mean_absolute_error(y_test,y_pred))
print(r2_score(y_test,y_pred))
# Out:
# 16235357969.714996
# 64222.635782929254
# 0.7101275066164858

# %%
pd.set_option("display.max_rows",None)

# %%
X.columns
# Out:
# Index(['city', 'bt', 'km', 'transmission', 'ownerNo', 'oem', 'modelYear',
#        'InsuranceValidity', 'FuelType', 'RTO', 'Top_features', 'Mileage',
#        'Engine', 'Max_Power', 'Torque', 'Seats', 'Color', 'NoofCylinder',
#        'ValuesperCylinder', 'TurboCharger', 'Length', 'Width', 'Height',
#        'WheelBase', 'GearBox', 'SteeringType', 'FrontBrakeType',
#        'RearBrakeType', 'NoDoorNumbers'],
#       dtype='object')

# %%
importances = model.feature_importances_

# Create a DataFrame for better visualization
feature_importance_df = pd.DataFrame({
    'Feature': X.columns,
    'Importance': importances
})

# Sort features by importance
feature_importance_df = feature_importance_df.sort_values(by='Importance', ascending=False)

# %%
feature_importance_df["Feature"][0:15]
# Out:
# 21           Width
# 6        modelYear
# 2               km
# 13       Max_Power
# 0             city
# 20          Length
# 9              RTO
# 23       WheelBase
# 22          Height
# 11         Mileage
# 16           Color
# 5              oem
# 24         GearBox
# 3     transmission
# 14          Torque
# Name: Feature, dtype: object

# %%
feature_importance_df["Feature"][15:]
# Out:
# 12               Engine
# 7     InsuranceValidity
# 10         Top_features
# 4               ownerNo
# 25         SteeringType
# 8              FuelType
# 19         TurboCharger
# 27        RearBrakeType
# 17         NoofCylinder
# 1                    bt
# 18    ValuesperCylinder
# 28        NoDoorNumbers
# 15                Seats
# 26       FrontBrakeType
# Name: Feature, dtype: object

# %%
X = df.drop(["price","Engine","Top_features","RTO","SteeringType","TurboCharger","RearBrakeType","NoofCylinder","ValuesperCylinder","NoDoorNumbers","Seats","FrontBrakeType"],axis=1)
y = df["price"]

# %%
X_train,X_test,y_train,y_test =train_test_split(X,y,test_size=0.25)

scaler1 = StandardScaler()
X_train_scaled = scaler1.fit_transform(X_train)

with open('scaler1.pkl', 'wb') as f:
    pickle.dump(scaler1, f)

X_test_scaled = scaler1.transform(X_test)

# %%
from sklearn.ensemble import RandomForestRegressor
model = RandomForestRegressor().fit(X_train_scaled,y_train)
y_pred=model.predict(X_test_scaled)
print(mean_squared_error(y_test,y_pred))
print(mean_absolute_error(y_test,y_pred))
print(r2_score(y_test,y_pred))
# Out:
# 18848671090.306175
# 66811.73228357537
# 0.663762917765845

# %%
from sklearn.ensemble import RandomForestRegressor
model = RandomForestRegressor(max_depth=20, n_estimators=200).fit(X_train_scaled,y_train)
y_pred=model.predict(X_test_scaled)
print(mean_squared_error(y_test,y_pred))
print(mean_absolute_error(y_test,y_pred))
print(r2_score(y_test,y_pred))
# Out:
# 18606134356.58142
# 65870.50900315559
# 0.6680894744388062

# %%
X.shape
# Out:
# (4509, 20)

# %%
#same accuracy so we fix with this columns

# %%
pickle.dump(model,open("carprice.pkl","wb"))

# %%
X.head()
# Out:
#    city  bt      km  transmission  ownerNo  oem  modelYear  InsuranceValidity  \
# 0     0   2  120000             1        3   20       2015                  2
# 1     0   7   32706             1        2    6       2018                  0
# 2     0   2   11949             1        1   29       2018                  0
# 3     0   8   17794             1        1    9       2014                  0
# 4     0   7   60000             1        1   20       2015                  2
#
#    FuelType  RTO  Top_features  Mileage  Max_Power  Torque  Color  Length  \
# 0         4   16             8    23.10      67.04   90.00     12  3715.0
# 1         4   16             9    17.00     121.31  150.00     12  3998.0
# 2         4   16             9    23.84      84.00  114.00     10  3746.0
# 3         4   16             9    19.10      81.86  113.75      8  3995.0
# 4         1   16             9    23.65      88.50  200.00      4  4300.0
#
#     Width  Height  WheelBase  GearBox
# 0  1635.0  1565.0     2425.0        5
# 1  1765.0  1647.0     2519.0        5
# 2  1647.0  1535.0     2400.0        5
# 3  1660.0  1520.0     2425.0        5
# 4  1785.0  1595.0     2600.0        5

# %%
with open('scaler1.pkl', 'rb') as f:
    loaded_scaler = pickle.load(f)

# %%
values = ([[0,1,120000,1,3,20,2015,2,4,23.10,67.04,90.0,12,3715.0,1635.0,1565.0,2425.0,5]])
values_scaled= loaded_scaler.transform(values)
# Out:
# C:\Users\shank\AppData\Roaming\Python\Python312\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
values_scaled
# Out:
# array([[-1.37247906, -1.09776371,  2.13946053,  0.44315986,  2.90690636,
#          0.49130275, -0.57186086,  0.71032585,  0.45090714,  0.98139256,
#         -1.00506115, -0.98883398,  1.05895599, -0.80003573, -0.76441953,
#          0.40329456, -0.58893102,  0.03104758]])

# %%
model
# Out:
# RandomForestRegressor(max_depth=20, n_estimators=200)

# %%
df.head()
# Out:
#    city  bt      km  transmission  ownerNo  oem  modelYear     price  \
# 0     0   2  120000             1        3   20       2015  400000.0
# 1     0   7   32706             1        2    6       2018  811000.0
# 2     0   2   11949             1        1   29       2018  585000.0
# 3     0   8   17794             1        1    9       2014  462000.0
# 4     0   7   60000             1        1   20       2015  790000.0
#
#    InsuranceValidity  FuelType  RTO  Top_features  Mileage  Engine  Max_Power  \
# 0                  2         4   16             8    23.10     998      67.04
# 1                  0         4   16             9    17.00    1497     121.31
# 2                  0         4   16             9    23.84    1199      84.00
# 3                  0         4   16             9    19.10    1197      81.86
# 4                  2         1   16             9    23.65    1248      88.50
#
#    Torque  Seats  Color  NoofCylinder  ValuesperCylinder  TurboCharger  \
# 0   90.00    5.0     12             3                  4             0
# 1  150.00    5.0     12             3                  4             0
# 2  114.00    5.0     10             3                  4             0
# 3  113.75    5.0      8             4                  4             0
# 4  200.00    5.0      4             4                  4             2
#
#    Length   Width  Height  WheelBase  GearBox  SteeringType  FrontBrakeType  \
# 0  3715.0  1635.0  1565.0     2425.0        5             3               0
# 1  3998.0  1765.0  1647.0     2519.0        5             3               0
# 2  3746.0  1647.0  1535.0     2400.0        5             3               0
# 3  3995.0  1660.0  1520.0     2425.0        5             3               0
# 4  4300.0  1785.0  1595.0     2600.0        5             3               0
#
#    RearBrakeType  NoDoorNumbers
# 0              1              5
# 1              1              4
# 2              1              5
# 3              1              4
# 4              0              5

# %%
car_price_pred =model.predict(values_scaled)
round(car_price_pred)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[164], line 2
#       1 car_price_pred =model.predict(values_scaled)
# ----> 2 round(car_price_pred)
#
# TypeError: type numpy.ndarray doesn't define __round__ method

# %%
round(car_price_pred[0])
# Out:
# 382290

# %%
X.columns
# Out:
# Index(['city', 'bt', 'km', 'transmission', 'ownerNo', 'oem', 'modelYear',
#        'InsuranceValidity', 'FuelType', 'Mileage', 'Max_Power', 'Torque',
#        'Color', 'Length', 'Width', 'Height', 'WheelBase', 'GearBox'],
#       dtype='object')
